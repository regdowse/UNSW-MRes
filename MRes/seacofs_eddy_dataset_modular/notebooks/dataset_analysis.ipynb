# %%
from pathlib import Path
import sys
import pandas as pd

import analysis_tools as at

PROJECT_ROOT = Path("~/UNSW-MRes/MRes/seacofs_eddy_dataset_modular").expanduser()

SRC = PROJECT_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from seacofs_eddy_dataset.config import load_config

CONFIG_PATH = PROJECT_ROOT / "config" / "local.yaml"
config = load_config(CONFIG_PATH)

# Grid
from seacofs_eddy_dataset.core.grid import read_reference_grid
from seacofs_eddy_dataset.stages.detection import reference_grid_path
grid = read_reference_grid(reference_grid_path(config))

# %%
df_eddies= pd.read_parquet(
    config.output_root / "processed" / "eddy_dataset_processed.parquet"
)
df_eddies.head()
# Out:
#    Eddy   Day Cyc         lon        lat   ic  jc          xc          yc  \
# 0     1  1462  CE  152.716333 -38.866383  171  26  474.560686  127.605656
# 1     1  1463  CE  152.836206 -38.814279  173  28  482.821993  136.635735
# 2     1  1464  CE  152.905198 -38.816261  175  28  488.606048  138.480541
# 3     1  1465  CE  152.719389 -38.902070  171  25  475.960098  123.953440
# 4     1  1466  CE  152.753007 -38.935135  172  25  479.803789  121.483614
#
#           w  ...       q11       q12       q22         Rc      psi0        AR  \
# 0 -0.000032  ...  1.758660 -0.532719  0.737370  29.449052  7.225911  1.973172
# 1 -0.000041  ...  1.617876 -0.538331  0.816358  29.449052  7.225911  1.859668
# 2 -0.000035  ...  1.393129 -0.557491  0.967292  32.090160  7.712683  1.745185
# 3 -0.000020  ...  1.129925 -0.374295  1.051020  34.827275  8.275696  1.433213
# 4 -0.000026  ...  1.026354 -0.135421  1.060328  37.564389  8.838709  1.140614
#
#            R  Age       Date  \
# 0  20.004291   26 1994-01-02
# 1  18.906549   26 1994-01-03
# 2  20.859920   26 1994-01-04
# 3  18.674495   26 1994-01-05
# 4  21.564028   26 1994-01-06
#
#                                                fname
# 0  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 1  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 2  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 3  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 4  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
#
# [5 rows x 21 columns]

# %%
df_vert = pd.read_parquet(
    config.output_root / "vertical_profiles_confirmed" / "profiles.parquet"
)
df_vert
# Out:
#          Eddy    Day  fnumber        Depth   z          xc          yc   ic  \
# 0           1   1462     1461     0.000000   0  474.560686  127.605656  171
# 1           1   1462     1461     5.879627   1  476.056668  129.678745  171
# 2           1   1462     1461    10.725783   2  476.887911  132.134805  172
# 3           1   1462     1461    16.383097   3  476.324558  136.117738  171
# 4           1   1462     1461    22.925581   4  478.387952  139.735396  172
# ...       ...    ...      ...          ...  ..         ...         ...  ...
# 2824604  2982  10650    10641   515.416489  19  508.963912  299.374668  180
# 2824605  2982  10650    10641   660.806374  20  508.678327  299.023082  180
# 2824606  2982  10650    10641   858.918478  21  508.485388  298.326056  180
# 2824607  2982  10650    10641  1128.898331  22  506.706507  297.269787  179
# 2824608  2982  10650    10641  1492.971178  23  503.950767  300.174268  178
#
#          jc         w       q11       q12       q22    Omega0     Omega  \
# 0        26 -0.000032  1.758660 -0.532719  0.737370       NaN -0.000013
# 1        26 -0.000030  1.628746 -0.329796  0.680748 -0.000013 -0.000013
# 2        27 -0.000030  1.593752 -0.319464  0.691486 -0.000013 -0.000014
# 3        28 -0.000033  1.776776 -0.280829  0.607204 -0.000014 -0.000016
# 4        28 -0.000034  1.787666 -0.425015  0.660435 -0.000014 -0.000017
# ...      ..       ...       ...       ...       ...       ...       ...
# 2824604  61 -0.000017  1.033282 -0.035786  0.969029 -0.000008 -0.000006
# 2824605  61 -0.000014  1.045371 -0.055566  0.959552 -0.000007 -0.000005
# 2824606  61 -0.000012  1.055097 -0.031142  0.948699 -0.000006 -0.000004
# 2824607  60 -0.000008  0.980631  0.030299  1.020688 -0.000004 -0.000003
# 2824608  61 -0.000006  0.773990  0.279376  1.392848 -0.000003 -0.000003
#
#                  Rc       psi0          R
# 0         29.449052   7.225911  20.004291
# 1         35.798824   8.596591  19.126716
# 2         33.615289   8.107898  21.330116
# 3         31.928536   8.213464  20.137241
# 4         30.093898   7.889563  21.334571
# ...             ...        ...        ...
# 2824604   75.695297  16.693750  45.049156
# 2824605   78.656868  15.933899  46.467550
# 2824606  101.415168  18.656178  62.280573
# 2824607  115.807964  18.668141  82.943966
# 2824608   96.370667  11.886137  61.421115
#
# [2824609 rows x 18 columns]
