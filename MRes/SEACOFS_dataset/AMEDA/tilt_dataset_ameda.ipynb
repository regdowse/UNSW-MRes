# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc

import sys
sys.path.append('/home/z5297792/UNSW-MRes/MRes/SEACOFS_dataset') 
from clim_functions import compute_tilt_data, bearing

# %%
df_ameda = pd.read_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/AMEDA/df_ameda_renamed.pkl')

# %%
dic_vert = pd.read_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/AMEDA/dic_vert_doppio_AMEDA.pkl')

# %%
dfs = [
    compute_tilt_data(dic_vert, eddy)
    for eddy in df_ameda.Eddy.unique()
]

df_tilt = pd.concat(dfs, ignore_index=True)
df_tilt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dfs = [
#       2     compute_tilt_data(dic_vert, eddy)
#       3     for eddy in df_ameda.Eddy.unique()
#       4 ]
#       6 df_tilt = pd.concat(dfs, ignore_index=True)
#       7 df_tilt
#
# Cell In[4], line 2, in <listcomp>(.0)
#       1 dfs = [
# ----> 2     compute_tilt_data(dic_vert, eddy)
#       3     for eddy in df_ameda.Eddy.unique()
#       4 ]
#       6 df_tilt = pd.concat(dfs, ignore_index=True)
#       7 df_tilt
#
# File ~/UNSW-MRes/MRes/SEACOFS_dataset/clim_functions.py:591, in compute_tilt_data(dic_all, eddy, num, depth_int, max_depth, min_depth_range, var, eps, min_points)
#     588 df = dic[day].copy()
#     590 if var == 'Depth':
# --> 591     df[var] = np.abs(df[var])
#     593 df = df[df[var] <= max_depth]
#     594 df = df.set_index(var).sort_index()
#
# File ~/myenv310/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/myenv310/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Depth'

# %%
df_tilt.to_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/AMEDA/df_tilt_ameda.pkl')
