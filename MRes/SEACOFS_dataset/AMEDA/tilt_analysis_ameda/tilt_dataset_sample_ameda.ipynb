# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc

import sys
sys.path.append('/home/z5297792/UNSW-MRes/MRes/SEACOFS_dataset') 
from clim_functions import compute_tilt_data, bearing

# sample_eddies = [159, 918, 1833, 3812, 20, 400, 3412]
sample_eddies = list(range(1,9))
sample_eddies
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
df_ameda = pd.read_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/AMEDA/df_ameda_renamed.pkl')

# %%
dic_vert = pd.read_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/AMEDA/dic_vert_doppio_AMEDA.pkl')
dic_vert_sample = {}
for eddy in sample_eddies:
    dic_vert_sample[f'Eddy{eddy}'] = dic_vert[f'Eddy{eddy}']

# %%
dfs = [
    compute_tilt_data(dic_vert_sample, eddy)
    for eddy in sample_eddies
]

df_tilt = pd.concat(dfs, ignore_index=True)
df_tilt
# Out:
#      Eddy   Day    TiltDis     TiltDir
# 0       1  1465  16.147158   80.585819
# 1       1  1466  19.455358   63.680275
# 2       1  1467  21.644105   51.282725
# 3       1  1468  21.790930   40.537267
# 4       1  1469  20.640665   32.035683
# ..    ...   ...        ...         ...
# 638     8  1482  10.813162  328.777078
# 639     8  1483  10.190488  334.105062
# 640     8  1484  10.689498  341.039214
# 641     8  1485  10.736807  348.627016
# 642     8  1487  10.948171  352.038157
#
# [643 rows x 4 columns]

# %%
df_tilt.to_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/AMEDA/df_tilt_sample_AMEDA.pkl')

# %%
# df_ameda[df_ameda.Day.diff()!=1]
