# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc

import sys
sys.path.append('/home/z5297792/UNSW-MRes/MRes/SEACOFS_dataset') 
from clim_functions import compute_tilt_data, bearing

sample_eddies = [100, 627, 1269, 2609, 34, 281, 2334, 3126]

# %%
df_eddies = pd.read_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_eddies_processed.pkl')

# %%
dic_vert = pd.read_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio_sample.pkl')

# %%
dfs = [
    compute_tilt_data(dic_vert, eddy)
    for eddy in sample_eddies
]

df_tilt = pd.concat(dfs, ignore_index=True)
df_tilt
# Out:
#      Eddy   Day    TiltDis     TiltDir
# 0     100  1677  13.152310  103.679783
# 1     100  1678  14.562882   77.128157
# 2     100  1679  18.837531   49.346119
# 3     100  1680  10.821965   20.127627
# 4     100  1681  18.732512  359.782567
# ..    ...   ...        ...         ...
# 853  3126  8963   3.906322  207.403333
# 854  3126  8964   5.469505  205.591777
# 855  3126  8965   6.222562  202.631119
# 856  3126  8966   5.127444  199.816892
# 857  3126  8967   3.589787  185.840726
#
# [858 rows x 4 columns]

# %%
df_tilt.to_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_tilt_sample.pkl')
