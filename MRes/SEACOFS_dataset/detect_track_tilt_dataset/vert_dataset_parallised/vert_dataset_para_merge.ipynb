# %%
import numpy as np
import pandas as pd
import os
import pickle

def merge_dic_vert(*dics):
    out = {}

    for dic in dics:
        for eddy_key, day_dic in dic.items():
            out.setdefault(eddy_key, {})

            for day_key, df in day_dic.items():
                if day_key in out[eddy_key]:
                    print(f'Warning: overwriting {eddy_key} {day_key}')

                out[eddy_key][day_key] = df

    return out


base_dir = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset'

part_files = [
    f'{base_dir}/dic_vert_doppio_para1.pkl',
    f'{base_dir}/dic_vert_doppio_para2.pkl',
    f'{base_dir}/dic_vert_doppio_para3.pkl',
    f'{base_dir}/dic_vert_doppio_para4.pkl',
]

dics = []

for file in part_files:
    if os.path.exists(file) and os.path.getsize(file) > 0:
        with open(file, 'rb') as f:
            dics.append(pickle.load(f))
        print(f'Loaded {file}')
    else:
        print(f'Skipping missing/empty file: {file}')

dic = merge_dic_vert(*dics)

out_file = f'{base_dir}/dic_vert_doppio.pkl'

tmp_file = out_file #+ '.tmp'
with open(tmp_file, 'wb') as f:
    pickle.dump(dic, f)

os.replace(tmp_file, out_file)

print(f'Saved merged dictionary to {out_file}')
print(f'Total eddies: {len(dic)}')
print(f'Total eddy-days: {sum(len(v) for v in dic.values())}')
# Out:
# Loaded /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio_para1.pkl
# Loaded /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio_para2.pkl
# Loaded /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio_para3.pkl
# Loaded /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio_para4.pkl
# Saved merged dictionary to /srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio.pkl
# Total eddies: 3842
# Total eddy-days: 157798
