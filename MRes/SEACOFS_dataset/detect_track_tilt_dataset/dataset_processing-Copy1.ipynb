# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc
from scipy.interpolate import RegularGridInterpolator

import sys
sys.path.append('/home/z5297792/UNSW-MRes/MRes/SEACOFS_dataset') 
from clim_functions import day_plot, compute_AR_from_Q

# %%
fname = f'/srv/scratch/z3533156/26year_BRAN2020/outer_avg_01461.nc'

dataset = nc.Dataset(fname)

lon_rho = np.transpose(dataset.variables['lon_rho'], axes=(1, 0))
lat_rho = np.transpose(dataset.variables['lat_rho'], axes=(1, 0))
mask_rho = np.transpose(dataset.variables['mask_rho'], axes=(1, 0))
h = np.transpose(dataset.variables['h'], axes=(1, 0))
# f = np.transpose(dataset.variables['f'], axes=(1, 0))
angle = dataset.variables['angle'][0, 0]
z_r = np.load('/srv/scratch/z5297792/z_r.npy')
z_r = np.transpose(z_r, (1, 2, 0))

def distance(lat1, lon1, lat2, lon2):
    EARTH_RADIUS = 6357
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return EARTH_RADIUS * 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

j_mid, i_mid = lon_rho.shape[1] // 2, lon_rho.shape[0] // 2

dx = distance(lat_rho[:-1, j_mid], lon_rho[:-1, j_mid],
              lat_rho[1:, j_mid], lon_rho[1:, j_mid])
dy = distance(lat_rho[i_mid, :-1], lon_rho[i_mid, :-1],
              lat_rho[i_mid, 1:], lon_rho[i_mid, 1:])

x_grid = np.insert(np.cumsum(dx), 0, 0)
y_grid = np.insert(np.cumsum(dy), 0, 0)
X_grid, Y_grid = np.meshgrid(x_grid, y_grid, indexing='ij')

# %%
fp = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_tracked.pkl'
df_tracked = pd.read_pickle(fp)
df_tracked['q11'] = [Q[0,0] for Q in df_tracked.Q]
df_tracked['q12'] = [Q[1,0] for Q in df_tracked.Q]
df_tracked['q22'] = [Q[1,1] for Q in df_tracked.Q]
df_tracked['AR'] = compute_AR_from_Q(np.stack(df_tracked['Q'].values))
df_tracked
# Out:
#           Day  fnumber    nxc     nyc Cyc          xc           yc         w  \
# 0        1462     1461  830.0  1515.0  AE  829.879126  1515.297884  0.000016
# 1        1462     1461  358.0  1408.0  AE  357.902634  1407.794571  0.000032
# 2        1462     1461  928.0  1356.0  CE  928.181752  1356.070550 -0.000011
# 3        1462     1461  506.0  1354.0  CE  505.750855  1353.499933 -0.000032
# 4        1462     1461  754.0  1285.0  AE  753.849693  1284.689807  0.000022
# ...       ...      ...    ...     ...  ..         ...          ...       ...
# 367189  10650    10641  349.0   158.0  AE  348.663439   158.138527  0.000033
# 367190  10650    10641  973.0   126.0  CE  978.294053   127.970950 -0.000004
# 367191  10650    10641  805.0    95.0  AE  804.765913    95.382012  0.000011
# 367192  10650    10641  157.0    34.0  CE  157.210669    33.449590 -0.000007
# 367193  10650    10641  662.0    13.0  CE  662.493367    12.691756 -0.000005
#
#                                                         Q    Omega0  ...  \
# 0       [[0.7054724746035225, -0.17299518294950286], [...  0.000007  ...
# 1       [[1.2525415454561337, -0.37318304544145586], [...  0.000015  ...
# 2       [[0.9184334895938384, -0.6568144522261018], [-... -0.000004  ...
# 3       [[1.0915204469734063, -0.17483272531676586], [... -0.000016  ...
# 4       [[1.300245004042572, -0.37537759847059776], [-...  0.000010  ...
# ...                                                   ...       ...  ...
# 367189  [[1.3863808771116255, 0.04649055064735413], [0...  0.000016  ...
# 367190  [[0.6233322936879349, -0.5502050858849237], [-... -0.000001  ...
# 367191  [[1.2619918374118362, 0.3980497594289241], [0....  0.000005  ...
# 367192  [[0.9874338034387458, 0.628992620695803], [0.6... -0.000003  ...
# 367193  [[0.8074064067247743, 0.12727284340477454], [0... -0.000003  ...
#
#                 R       err  Omega0_abs  eddy_idx   Eddy  next_num       q11  \
# 0       63.384028  0.321474    0.000007         0      0     74927  0.705472
# 1       50.068171  0.227335    0.000015         1      1     74927  1.252542
# 2       74.597458  0.194964    0.000004         2      2     74927  0.918433
# 3       69.457705  0.558695    0.000016         3      3     74927  1.091520
# 4       65.961546  0.344691    0.000010         4      4     74927  1.300245
# ...           ...       ...         ...       ...    ...       ...       ...
# 367189  43.099927  0.363955    0.000016        22  74889     74927  1.386381
# 367190  34.482872  5.649039    0.000001        23  74906     74927  0.623332
# 367191  45.893895  0.448028    0.000005        24  74859     74927  1.261992
# 367192  34.764443  0.589349    0.000003        25  74826     74927  0.987434
# 367193  31.106318  0.581744    0.000003        26  74815     74927  0.807406
#
#              q12       q22        AR
# 0      -0.172995  1.459911  1.497688
# 1      -0.373183  0.909563  1.491752
# 2      -0.656814  1.558529  1.969122
# 3      -0.174833  0.944157  1.207563
# 4      -0.375378  0.877456  1.519659
# ...          ...       ...       ...
# 367189  0.046491  0.722862  1.389622
# 367190 -0.550205  2.089938  2.273400
# 367191  0.398050  0.917949  1.523600
# 367192  0.628993  1.413393  1.864486
# 367193  0.127273  1.258596  1.292021
#
# [367194 rows x 23 columns]

# %%
df = df_tracked.copy()
df.hist(['w', 'Omega', 'Rc', 'AR', 'psi0'])
plt.tight_layout()
df.head()
# Out:
#     Day  fnumber    nxc     nyc Cyc          xc           yc         w  \
# 0  1462     1461  830.0  1515.0  AE  829.879126  1515.297884  0.000016
# 1  1462     1461  358.0  1408.0  AE  357.902634  1407.794571  0.000032
# 2  1462     1461  928.0  1356.0  CE  928.181752  1356.070550 -0.000011
# 3  1462     1461  506.0  1354.0  CE  505.750855  1353.499933 -0.000032
# 4  1462     1461  754.0  1285.0  AE  753.849693  1284.689807  0.000022
#
#                                                    Q    Omega0  ...  \
# 0  [[0.7054724746035225, -0.17299518294950286], [...  0.000007  ...
# 1  [[1.2525415454561337, -0.37318304544145586], [...  0.000015  ...
# 2  [[0.9184334895938384, -0.6568144522261018], [-... -0.000004  ...
# 3  [[1.0915204469734063, -0.17483272531676586], [... -0.000016  ...
# 4  [[1.300245004042572, -0.37537759847059776], [-...  0.000010  ...
#
#            R       err  Omega0_abs  eddy_idx  Eddy  next_num       q11  \
# 0  63.384028  0.321474    0.000007         0     0     74927  0.705472
# 1  50.068171  0.227335    0.000015         1     1     74927  1.252542
# 2  74.597458  0.194964    0.000004         2     2     74927  0.918433
# 3  69.457705  0.558695    0.000016         3     3     74927  1.091520
# 4  65.961546  0.344691    0.000010         4     4     74927  1.300245
#
#         q12       q22        AR
# 0 -0.172995  1.459911  1.497688
# 1 -0.373183  0.909563  1.491752
# 2 -0.656814  1.558529  1.969122
# 3 -0.174833  0.944157  1.207563
# 4 -0.375378  0.877456  1.519659
#
# [5 rows x 23 columns]

# %%
def filter_outliers(df_doppio, threshold=4):

    df = df_doppio.copy()

    df['Omega_abs'] = df['Omega'].abs()
    df['psi0_abs'] = df['psi0'].abs()

    cols = ['Omega_abs', 'AR', 'psi0_abs']

    keep_cols = [
        'Day', 'Eddy', 'Cyc', 'lon', 'lat', 'ic', 'jc', 'xc', 'yc',
        'Omega0', 'R', 'Age', 'Date', 'fname'
    ]

    valid_mask = df[['Eddy', 'Rc', 'R'] + cols].notna().all(axis=1)

    sanity_mask = (
        (df['Omega_abs'] > 0)
        & (df['AR'] >= 1)
        & (df['psi0_abs'] > 0)
    )

    Rc_mask = df['Rc'] < 1.75 * df['R']

    outlier_mask = pd.Series(True, index=df.index)

    for eddy, g in df.loc[valid_mask].groupby('Eddy'):

        med = g[cols].median()
        mad = (g[cols] - med).abs().median().replace(0, np.nan)

        lower = med - threshold * mad / 0.6745
        upper = med + threshold * mad / 0.6745

        lower['Omega_abs'] = max(lower['Omega_abs'], 0)
        lower['AR'] = max(lower['AR'], 1)
        lower['psi0_abs'] = max(lower['psi0_abs'], 0)

        mask = ((g[cols] >= lower) & (g[cols] <= upper)).all(axis=1)

        outlier_mask.loc[g.index] = mask

    final_mask = (
        valid_mask
        & sanity_mask
        & Rc_mask
        & outlier_mask
    )

    cols_to_nan = df.columns.difference(keep_cols)

    df.loc[~final_mask, cols_to_nan] = np.nan

    print(f'Flagged {len(df) - final_mask.sum()} rows as invalid')
    print(f'Rows retained structurally: {len(df)}')
    print(f'Rows with valid DOPPIO values: {final_mask.sum()}')

    return df.reset_index(drop=True)

# %%
df_tracked_clean = filter_outliers(df_tracked)
# df_tracked_clean = df_tracked.copy()
# Out:
# Flagged 245226 rows as invalid
# Rows retained structurally: 367194
# Rows with valid DOPPIO values: 121968

# %%
# Find Mesoscale
df_eddies = df_tracked_clean[['Eddy', 'Day', 'Cyc', 'xc', 'yc', 'w', 'Omega', 'q11', 'q12', 'q22', 'Rc', 'psi0', 'AR', 'R']].copy().sort_values(by=['Eddy', 'Day'])
df_eddies = df_eddies.groupby('Eddy').filter(lambda g: g['Day'].max() - g['Day'].min() >= 21) # Keep only mesoscale - older than 3 weeks
df_eddies['Eddy'] = df_eddies['Eddy'].rank(method='dense').astype(int) # Relabel the Eddy's 1,2,3..
df_eddies = df_eddies.reset_index(drop=True)

# %%
df = df_eddies.copy()
df.hist(['w', 'Omega', 'Rc', 'AR', 'psi0'])
plt.tight_layout()

# %%
# Find Lon and Lat values
xg, yg = x_grid, y_grid
lon_interp = RegularGridInterpolator((yg, xg), lon_rho.T, bounds_error=False, fill_value=np.nan)
lat_interp = RegularGridInterpolator((yg, xg), lat_rho.T, bounds_error=False, fill_value=np.nan)
points = np.column_stack((df_eddies['yc'].to_numpy(), df_eddies['xc'].to_numpy()))
df_eddies['lon'] = lon_interp(points)
df_eddies['lat'] = lat_interp(points)
# Re order columns
cols = df_eddies.columns.tolist()
i = cols.index('Cyc') + 1
base = [c for c in cols if c not in ('lon','lat')]
new_order = base[:i] + ['lon','lat'] + base[i:]
df_eddies = df_eddies[new_order].reset_index(drop=True)
df_eddies

df_eddies
# Out:
#         Eddy    Day Cyc         lon        lat          xc           yc  \
# 0          1   1462  CE  161.072036 -29.736582  928.181752  1356.070550
# 1          1   1463  CE  160.820027 -29.753172  905.254559  1345.866439
# 2          1   1464  CE  160.892701 -29.754904  912.061191  1348.117301
# 3          1   1465  CE  160.929437 -29.612368  911.162024  1364.461638
# 4          1   1466  CE  160.908986 -29.586156  908.463829  1366.554462
# ...      ...    ...  ..         ...        ...         ...          ...
# 141820  3990  10646  CE  155.134295 -40.092889  711.617369    69.895295
# 141821  3990  10647  CE  154.883954 -40.396445  699.853461    30.349325
# 141822  3990  10648  CE  155.001742 -40.518521  713.016589    20.865525
# 141823  3990  10649  CE  155.187153 -40.282064  721.413917    51.393389
# 141824  3990  10650  CE  154.414199 -40.433036  662.493367    12.691756
#
#                w     Omega       q11       q12       q22          Rc  \
# 0      -0.000011 -0.000007  0.918433 -0.656814  1.558529  118.032741
# 1      -0.000018 -0.000009  1.537559 -0.243165  0.688838  108.004573
# 2            NaN       NaN       NaN       NaN       NaN         NaN
# 3      -0.000016 -0.000009  1.404286 -0.325607  0.787603  111.650721
# 4      -0.000014 -0.000009  1.181141 -0.435550  1.007249  115.925719
# ...          ...       ...       ...       ...       ...         ...
# 141820 -0.000008 -0.000006  1.298510 -0.012157  0.770227   57.890310
# 141821       NaN       NaN       NaN       NaN       NaN         NaN
# 141822       NaN       NaN       NaN       NaN       NaN         NaN
# 141823 -0.000007 -0.000005  1.084107 -0.013859  0.922595   69.660948
# 141824       NaN       NaN       NaN       NaN       NaN         NaN
#
#              psi0        AR          R
# 0       47.992205  1.969122  74.597458
# 1       52.019741  1.602291  68.599374
# 2             NaN       NaN  78.300764
# 3       56.591801  1.544380  69.625773
# 4       57.471319  1.538338  72.613632
# ...           ...       ...        ...
# 141820  10.534469  1.298789  54.275882
# 141821        NaN       NaN  46.817975
# 141822        NaN       NaN  46.695383
# 141823  11.131844  1.085288  47.190073
# 141824        NaN       NaN  31.106318
#
# [141825 rows x 16 columns]

# %%
# Fill in missing eddy data
def interpolate_eddy_tracks(df):
    df = df.copy()
    df_interp = []

    for eddy_id, group in df.groupby('Eddy'):
        # Build a full range of days for this eddy
        full_days = pd.DataFrame({'Day': range(group['Day'].min(), group['Day'].max() + 1)})
        full_days['Eddy'] = eddy_id

        # Merge to reindex with all days, keeping columns of interest
        merged = pd.merge(full_days, group, on=['Eddy', 'Day'], how='left')

        # Interpolate numerical columns
        merged['lon'] = merged['lon'].interpolate()
        merged['lat'] = merged['lat'].interpolate()
        merged['xc'] = merged['xc'].interpolate()
        merged['yc'] = merged['yc'].interpolate()

        merged['w'] = merged['w'].interpolate()
        merged['Omega'] = merged['Omega'].interpolate()
        merged['q11'] = merged['q11'].interpolate()
        merged['q12'] = merged['q12'].interpolate()
        merged['q22'] = merged['q22'].interpolate()

        merged['Rc'] = merged['Rc'].interpolate()
        merged['psi0'] = merged['psi0'].interpolate()
        merged['AR'] = merged['AR'].interpolate()
        merged['R'] = merged['R'].interpolate()

        # Fill categorical column
        merged['Cyc'] = merged['Cyc'].ffill().bfill()

        df_interp.append(merged)

    df_result = pd.concat(df_interp, ignore_index=True).sort_values(by=['Eddy', 'Day'])

    return df_result

df_eddies = interpolate_eddy_tracks(df_eddies)

# %%
df_eddies = df_eddies.groupby('Eddy').filter(lambda g: g['R'].mean() > 15).reset_index(drop=True)

df_eddies['Age'] = df_eddies.groupby('Eddy')['Eddy'].transform('count')

df_eddies['Date'] = pd.Timestamp('1990-01-01') + pd.to_timedelta(df_eddies.Day, unit='D')
fnames = [
    f"/srv/scratch/z3533156/26year_BRAN2020/outer_avg_{1461 + ((day - 1462) // 30) * 30:05}.nc"
    for day in df_eddies['Day']
]
df_eddies['fname'] = fnames

ix = np.abs(df_eddies['xc'].values[:, None] - x_grid).argmin(axis=1)
iy = np.abs(df_eddies['yc'].values[:, None] - y_grid).argmin(axis=1)
idx = df_eddies.columns.get_loc('lat') + 1
df_eddies.insert(idx, 'ic', ix)
df_eddies.insert(idx + 1, 'jc', iy)

df_eddies
# Out:
#           Day  Eddy Cyc         lon        lat   ic   jc          xc  \
# 0        1462     1  CE  161.072036 -29.736582  261  274  928.181752
# 1        1463     1  CE  160.820027 -29.753172  257  272  905.254559
# 2        1464     1  CE  160.892701 -29.754904  258  273  912.061191
# 3        1465     1  CE  160.929437 -29.612368  258  276  911.162024
# 4        1466     1  CE  160.908986 -29.586156  258  277  908.463829
# ...       ...   ...  ..         ...        ...  ...  ...         ...
# 160089  10646  3990  CE  155.134295 -40.092889  223   14  711.617369
# 160090  10647  3990  CE  154.883954 -40.396445  221    6  699.853461
# 160091  10648  3990  CE  155.001742 -40.518521  223    4  713.016589
# 160092  10649  3990  CE  155.187153 -40.282064  225   10  721.413917
# 160093  10650  3990  CE  154.414199 -40.433036  214    3  662.493367
#
#                  yc         w  ...       q11       q12       q22          Rc  \
# 0       1356.070550 -0.000011  ...  0.918433 -0.656814  1.558529  118.032741
# 1       1345.866439 -0.000018  ...  1.537559 -0.243165  0.688838  108.004573
# 2       1348.117301 -0.000017  ...  1.470922 -0.284386  0.738221  109.827647
# 3       1364.461638 -0.000016  ...  1.404286 -0.325607  0.787603  111.650721
# 4       1366.554462 -0.000014  ...  1.181141 -0.435550  1.007249  115.925719
# ...             ...       ...  ...       ...       ...       ...         ...
# 160089    69.895295 -0.000008  ...  1.298510 -0.012157  0.770227   57.890310
# 160090    30.349325 -0.000007  ...  1.227042 -0.012724  0.821017   61.813856
# 160091    20.865525 -0.000007  ...  1.155574 -0.013292  0.871806   65.737402
# 160092    51.393389 -0.000007  ...  1.084107 -0.013859  0.922595   69.660948
# 160093    12.691756 -0.000007  ...  1.084107 -0.013859  0.922595   69.660948
#
#              psi0        AR          R  Age       Date  \
# 0       47.992205  1.969122  74.597458  107 1994-01-02
# 1       52.019741  1.602291  68.599374  107 1994-01-03
# 2       54.305771  1.573335  78.300764  107 1994-01-04
# 3       56.591801  1.544380  69.625773  107 1994-01-05
# 4       57.471319  1.538338  72.613632  107 1994-01-06
# ...           ...       ...        ...  ...        ...
# 160089  10.534469  1.298789  54.275882   22 2019-02-24
# 160090  10.733594  1.227622  46.817975   22 2019-02-25
# 160091  10.932719  1.156455  46.695383   22 2019-02-26
# 160092  11.131844  1.085288  47.190073   22 2019-02-27
# 160093  11.131844  1.085288  31.106318   22 2019-02-28
#
#                                                     fname
# 0       /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 1       /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 2       /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 3       /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 4       /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# ...                                                   ...
# 160089  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 160090  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 160091  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 160092  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
# 160093  /srv/scratch/z3533156/26year_BRAN2020/outer_av...
#
# [160094 rows x 21 columns]

# %%
(df_eddies.Rc - df_eddies.R).abs().hist(bins=100)
# Out:
# <Axes: >

# %%
df = df_eddies.copy()
df.hist(['w', 'Omega', 'Rc', 'AR', 'psi0'])
plt.tight_layout()

# %%
# path = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_eddies_processed.pkl'
# df_eddies.to_pickle(path)

# %%
day_plot(2275, df_eddies, out_core_flag=True)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# /home/z5297792/myenv310/lib/python3.10/site-packages/matplotlib/colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
