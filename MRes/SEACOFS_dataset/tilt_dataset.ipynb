# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc

from clim_functions import compute_tilt_data

# %%
fp = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_eddies_processed.pkl'
df_eddies = pd.read_pickle(fp)

# %%
fp = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio.pkl'
dic_vert = pd.read_pickle(fp)

# %%
# eddys, days, diffs = [], [], []
# for _, row in df_eddies.iterrows():
#     df = dic_vert.get(f'Eddy{int(row.Eddy)}', {}).get(f'Day{int(row.Day)}')

#     if df is not None and len(df) >= 2:
#         x0, y0 = df.iloc[0][['xc', 'yc']]
#         x1, y1 = df.iloc[1][['xc', 'yc']]
#         diffs.append(np.hypot(x0 - x1, y0 - y1))
#         eddys.append(int(row.Eddy)); days.append(int(row.Day));
# df_diff = pd.DataFrame({'Eddy': eddys, 'Day': days, 'diff': diffs})

# %%
# df_big = df_diff[df_diff['diff']>95].copy()
# df_big

# %%
# for k in range(len(df_big)):
#     row = df_big.iloc[k]
#     df = dic[f'Eddy{int(row.Eddy)}'][f'Day{int(row.Day)}']
#     plt.plot(df.xc, -df.Depth)

# %%
dfs = [
    compute_tilt_data(dic_vert, eddy)
    for eddy in df_eddies.Eddy.unique()
]

df_tilt = pd.concat(dfs, ignore_index=True)
df_tilt
