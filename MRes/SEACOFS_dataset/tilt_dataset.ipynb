# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc

from clim_functions import compute_tilt_data, bearing

# %%
fp = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_eddies_processed.pkl'
df_eddies = pd.read_pickle(fp)

# %%
fp = '/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/dic_vert_doppio.pkl'
dic_vert = pd.read_pickle(fp)

# %%
dfs = [
    compute_tilt_data(dic_vert, eddy)
    for eddy in df_eddies.Eddy.unique()
]

df_tilt = pd.concat(dfs, ignore_index=True)
df_tilt
# Out:
# /scratch/pbs.7811178.kman.restech.unsw.edu.au/ipykernel_1125261/3508682885.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_tilt = pd.concat(dfs, ignore_index=True)
#        Eddy    Day    TiltDis     TiltDir
# 0         1   1465  33.975521  184.917296
# 1         1   1466  30.064961  181.172744
# 2         1   1467  23.787315  175.742706
# 3         1   1468  18.534958  166.932661
# 4         1   1469  15.370667  149.807911
# ...     ...    ...        ...         ...
# 65795  2826  10643   0.247774  224.894978
# 65796  2826  10644   0.519966  292.927787
# 65797  2826  10645   0.467016  325.050708
# 65798  2826  10646   0.752301    4.278077
# 65799  2826  10647   1.165619   28.370574
#
# [65800 rows x 4 columns]

# %%
df_tilt.to_pickle('/srv/scratch/z5297792/SEACOFS_26yr_eddy_dataset/df_tilt.pkl')
