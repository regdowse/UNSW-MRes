# %%
import numpy as np

fnumbers = range(1461, 10641+1, 30)

sum_all = None
cnt_all = None

for fnum in fnumbers:
    N2 = np.load(f'/srv/scratch/z5297792/Climatology/N2s/N2s/N2_{fnum:05}.npy')
    
    if sum_all is None:
        sum_all = np.nansum(N2, axis=3)
        cnt_all = np.sum(~np.isnan(N2), axis=3).astype(np.int64)
    else:
        sum_all += np.nansum(N2, axis=3)
        cnt_all += np.sum(~np.isnan(N2), axis=3)
    print(fnum)

N2_ave = np.divide(sum_all, cnt_all, out=np.full_like(sum_all, np.nan), where=cnt_all!=0)
np.save('/srv/scratch/z5297792/Climatology/N2s/N2_ave.npy', N2_ave)
# Out:
# 1461
# 1491
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 16
#      14     else:
#      15         sum_all += np.nansum(N2, axis=3)
# ---> 16         cnt_all += np.sum(~np.isnan(N2), axis=3)
#      17     print(fnum)
#      19 N2_ave = np.divide(sum_all, cnt_all, out=np.full_like(sum_all, np.nan), where=cnt_all!=0)
#
# File ~/myenv310/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:2466, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2463         return out
#    2464     return res
# -> 2466 return _wrapreduction(
#    2467     a, np.add, 'sum', axis, dtype, out,
#    2468     keepdims=keepdims, initial=initial, where=where
#    2469 )
#
# File ~/myenv310/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:
