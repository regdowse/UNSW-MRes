# %%
import numpy as np
import netCDF4 as nc

CurSpeed_sum = np.load('/srv/scratch/z5297792/Climatology/ow_and_cur_speeds/cur_speed_01461.npy')


fnumbers = [f'{num:05}' for num in range(1491, 10611+1, 30)]

i = 0
for fnumber in fnumbers:

    CurSpeed = np.load('/srv/scratch/z5297792/Climatology/ow_and_cur_speeds/cur_speed_'+fnumber+'.npy')
    CurSpeed_sum = CurSpeed_sum + CurSpeed

    if i % 10 == 0:
        print(fnumber)
    i += 1

    del CurSpeed

CurSpeed_ave = CurSpeed_sum / (len(fnumbers)+1)

CurSpeed_ave = np.mean(CurSpeed_ave, axis=3)

np.save('/srv/scratch/z5297792/Climatology/CurSpeed_ave.npy', CurSpeed_ave)
# Out:
# 01521
# 01551
# 01581
# 01611
# 01641
# 01671
# 01701
# 01731
# 01761
# 01821
# 01851
# 01881
# 01911
# 01941
# 01971
# 02001
# 02031
# 02061
# 02121
# 02151
# 02181
# 02211
# 02241
# 02271
# 02301
# 02331
# 02361
# 02421
# 02451
# 02481
# 02511
# 02541
# 02571
# 02601
# 02631
# 02661
# 02721
# 02751
# 02781
# 02811
# 02841
# 02871
# 02901
# 02931
# 02961
# 03021
# 03051
# 03081
# 03111
# 03141
# 03171
# 03201
# 03231
# 03261
# 03321
# 03351
# 03381
# 03411
# 03441
# 03471
# 03501
# 03531
# 03561
# 03621
# 03651
# 03681
# 03711
# 03741
# 03771
# 03801
# 03831
# 03861
# 03921
# 03951
# 03981
# 04011
# 04041
# 04071
# 04101
# 04131
# 04161
# 04221
# 04251
# 04281
# 04311
# 04341
# 04371
# 04401
# 04431
# 04461
# 04521
# 04551
# 04581
# 04611
# 04641
# 04671
# 04701
# 04731
# 04761
# 04821
# 04851
# 04881
# 04911
# 04941
# 04971
# 05001
# 05031
# 05061
# 05121
# 05151
# 05181
# 05211
# 05241
# 05271
# 05301
# 05331
# 05361
# 05421
# 05451
# 05481
# 05511
# 05541
# 05571
# 05601
# 05631
# ...
