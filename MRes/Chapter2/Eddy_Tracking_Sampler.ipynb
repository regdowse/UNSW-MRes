# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import griddata
import netCDF4 as nc
from scipy.interpolate import RegularGridInterpolator
import time

# %%
# def tracking(df_data, start_ID, next_num, VORT_WEIGHT=15000, R_THRESH=30):
#     tic = time.perf_counter()

#     df_data = df_data.copy()
#     # Initialize IDs: set first day IDs equal to their Eddy values.
#     min_day = df_data['Day'].min()
#     df_data['ID'] = -1
#     df_data.loc[df_data['Day'] == min_day, 'ID'] = start_ID # for the initial dataset
#     df_data['ID'] = df_data['ID'].astype('Int64')
#     # next_num = df_data['ID'].max() + 1 # for the initial dataset

#     df_R = pd.DataFrame(columns=['D_diff', 'W_diff', 'R'])

#     # Loop through days starting from min_day+1 to max_day.
#     for day in range(min_day + 1, df_data['Day'].max() + 1):
#         pres_day = df_data[df_data['Day'] == day].copy()
#         pres_day = pres_day[~np.isnan(pres_day['x0'])]
#         for e_pres in pres_day['Eddy'].unique():
#             pres_eddy = pres_day[pres_day['Eddy'] == e_pres].iloc[0]
#             assigned = False
#             # Look back up to 4 days.
#             for delta in range(1, 5):
#                 candidate_day = day - delta
#                 if candidate_day < 0:
#                     continue
#                 candidate_prev = df_data[df_data['Day'] == candidate_day].copy()
#                 candidate_prev = candidate_prev[~np.isnan(candidate_prev['x0'])]
#                 for e_prev in candidate_prev['Eddy'].unique():
#                     prev_eddy = candidate_prev[candidate_prev['Eddy'] == e_prev].iloc[0]
#                     R = np.sqrt(
#                         (pres_eddy['x0'] - prev_eddy['x0'])**2 +
#                         (pres_eddy['y0'] - prev_eddy['y0'])**2 +
#                         VORT_WEIGHT * (pres_eddy['w'] - prev_eddy['w'])**2 
#                     )
#                     D_diff = np.hypot(pres_eddy['x0'] - prev_eddy['x0'], pres_eddy['y0'] - prev_eddy['y0'])
#                     W_diff = np.abs(pres_eddy['w'] - prev_eddy['w'])
#                     df_R.loc[len(df_R)] = {'D_diff': D_diff, 'W_diff': W_diff, 'R': R}
#                     if R < R_THRESH and (pres_eddy['Cyc'] == prev_eddy['Cyc']) and not (pres_day['ID'] == prev_eddy['ID']).any():
#                         df_data.loc[(df_data['Day'] == day) & (df_data['Eddy'] == e_pres), 'ID'] = prev_eddy['ID']
#                         assigned = True
#                         break
#                 if assigned:
#                     break
#             if not assigned:
#                 df_data.loc[(df_data['Day'] == day) & (df_data['Eddy'] == e_pres), 'ID'] = next_num
#                 next_num += 1

#         if day % 10 == 0:
#             toc = time.perf_counter()
#             print(f"Elapsed time: {toc - tic:.4f} seconds")
#             print(day)

#     df_data['next_num'] = next_num
                
#     return df_data, df_R

# %%
def tracking(df_data, start_ID, next_num, VORT_WEIGHT=15000, R_THRESH=30):

    tic = time.perf_counter()

    # Work on a copy so as not to modify the original DataFrame.
    df_data = df_data.copy()
    
    # Initialize IDs: set first day IDs equal to start_ID.
    min_day = df_data['Day'].min()
    df_data['ID'] = -1
    df_data.loc[df_data['Day'] == min_day, 'ID'] = start_ID  # for the initial dataset
    df_data['ID'] = df_data['ID'].astype('Int64')

    # Precompute a dictionary mapping each day to the indices of rows where 'x0' is not NaN.
    unique_days = sorted(df_data['Day'].unique())
    day_dict = {
        d: df_data.index[(df_data['Day'] == d) & (~df_data['x0'].isna())]
        for d in unique_days
    }

    # Use a list to collect R values rather than appending row-by-row to a DataFrame.
    df_R_rows = []
    
    max_day = df_data['Day'].max()
    for day in range(min_day + 1, max_day + 1):
        # Skip this day if no valid rows exist.
        if day not in day_dict or len(day_dict[day]) == 0:
            continue

        # Get all rows for the current day with valid x0.
        pres_day = df_data.loc[day_dict[day]]
        unique_eddies = pres_day['Eddy'].unique()

        for e_pres in unique_eddies:
            # Get the first occurrence for this eddy.
            pres_eddy = pres_day[pres_day['Eddy'] == e_pres].iloc[0]
            assigned = False

            # Look back up to 4 days.
            for delta in range(1, 5):
                candidate_day = day - delta
                if candidate_day < min_day:
                    continue
                if candidate_day not in day_dict or len(day_dict[candidate_day]) == 0:
                    continue

                # Get candidate previous day rows.
                candidate_prev = df_data.loc[day_dict[candidate_day]]
                # Group by 'Eddy' and take the first row for each unique eddy while preserving original order.
                candidate_group = candidate_prev.groupby('Eddy', as_index=False, sort=False).first()

                for _, prev_eddy in candidate_group.iterrows():
                    # Compute differences and R value.
                    dx = pres_eddy['x0'] - prev_eddy['x0']
                    dy = pres_eddy['y0'] - prev_eddy['y0']
                    dw = pres_eddy['w'] - prev_eddy['w']
                    R = np.sqrt(dx ** 2 + dy ** 2 + VORT_WEIGHT * (dw ** 2))
                    D_diff = np.hypot(dx, dy)
                    W_diff = np.abs(dw)
                    df_R_rows.append({'D_diff': D_diff, 'W_diff': W_diff, 'R': R})

                    # Check if current candidate meets the criteria.
                    if (R < R_THRESH) and (pres_eddy['Cyc'] == prev_eddy['Cyc']) and not (pres_day['ID'] == prev_eddy['ID']).any():
                        df_data.loc[(df_data['Day'] == day) & (df_data['Eddy'] == e_pres), 'ID'] = prev_eddy['ID']
                        assigned = True
                        break

                if assigned:
                    break

            if not assigned:
                df_data.loc[(df_data['Day'] == day) & (df_data['Eddy'] == e_pres), 'ID'] = next_num
                next_num += 1

        # Periodically print progress every 10 days.
        if day % 200 == 0:
            toc = time.perf_counter()
            print(f"Elapsed time: {toc - tic:.4f} seconds")
            print(day)

    # Convert the accumulated R values list to a DataFrame.
    df_R = pd.DataFrame(df_R_rows)
    df_data['next_num'] = next_num

    return df_data, df_R

# %%
intervals = [1611, 2211, 5479]

for k in range(len(intervals) - 2):
    
    start_day, end_day = intervals[k+1], intervals[k+2]
    
    df_data = pd.read_pickle(f"/srv/scratch/z5297792/Chapter2/df_data_1462_5479.pkl")
    df_data = df_data.dropna().copy() # If ESPRA didnt work then we dont have vorticity, which is required for tracking
    df_data = df_data[(df_data['Day']>=start_day)&(df_data['Day']<=end_day)]
    
    df_eddies_pre = pd.read_pickle(f"/srv/scratch/z5297792/Chapter2/df_eddies_{intervals[k]}_{start_day}.pkl")

    tic = time.perf_counter()
    start_ID = df_eddies_pre[df_eddies_pre['Day']==start_day]['ID'] # should be the max day
    next_num = df_eddies_pre.iloc[0]['next_num']
    df_eddies, df_R = tracking(df_data, start_ID, next_num)
    
    toc = time.perf_counter()
    print(f"Elapsed time: {toc - tic:.4f} seconds")

    df_eddies.to_pickle(f"/srv/scratch/z5297792/Chapter2/df_eddies_{start_day}_{end_day}.pkl")
    df_R.to_pickle(f"/srv/scratch/z5297792/Chapter2/df_R_{start_day}_{end_day}.pkl")
# Out:
# Elapsed time: 2.3863 seconds
# 2220
# Elapsed time: 4.4644 seconds
# 2230
# Elapsed time: 6.8405 seconds
# 2240
# Elapsed time: 8.5141 seconds
# 2250
# Elapsed time: 10.2859 seconds
# 2260
# Elapsed time: 12.2359 seconds
# 2270
# Elapsed time: 13.8195 seconds
# 2280
# Elapsed time: 15.4454 seconds
# 2290
# Elapsed time: 18.0423 seconds
# 2300
# Elapsed time: 20.5009 seconds
# 2310
# Elapsed time: 22.6904 seconds
# 2320
# Elapsed time: 25.7236 seconds
# 2330
# Elapsed time: 28.1031 seconds
# 2340
# Elapsed time: 31.2240 seconds
# 2350
# Elapsed time: 33.8563 seconds
# 2360
# Elapsed time: 37.2073 seconds
# 2370
# Elapsed time: 40.5544 seconds
# 2380
# Elapsed time: 43.8747 seconds
# 2390
# Elapsed time: 46.8877 seconds
# 2400
# Elapsed time: 50.3043 seconds
# 2410
# Elapsed time: 53.5363 seconds
# 2420
# Elapsed time: 58.0464 seconds
# 2430
# Elapsed time: 61.9942 seconds
# 2440
# Elapsed time: 65.1091 seconds
# 2450
# Elapsed time: 68.9638 seconds
# 2460
# Elapsed time: 72.1826 seconds
# 2470
# Elapsed time: 75.5323 seconds
# 2480
# Elapsed time: 78.6618 seconds
# 2490
# Elapsed time: 82.2157 seconds
# 2500
# Elapsed time: 84.9550 seconds
# 2510
# Elapsed time: 88.3216 seconds
# 2520
# Elapsed time: 91.9305 seconds
# 2530
# Elapsed time: 94.8555 seconds
# 2540
# Elapsed time: 96.9559 seconds
# 2550
# Elapsed time: 99.5420 seconds
# 2560
# Elapsed time: 101.6014 seconds
# 2570
# Elapsed time: 103.8087 seconds
# 2580
# Elapsed time: 105.7462 seconds
# 2590
# Elapsed time: 107.7637 seconds
# 2600
# Elapsed time: 109.9052 seconds
# 2610
# Elapsed time: 111.9197 seconds
# 2620
# Elapsed time: 113.7242 seconds
# 2630
# Elapsed time: 116.3718 seconds
# 2640
# Elapsed time: 119.1744 seconds
# 2650
# Elapsed time: 121.7476 seconds
# 2660
# Elapsed time: 125.1047 seconds
# 2670
# Elapsed time: 128.0318 seconds
# 2680
# Elapsed time: 130.6938 seconds
# 2690
# Elapsed time: 133.6468 seconds
# 2700
# Elapsed time: 137.1853 seconds
# 2710
# Elapsed time: 141.4594 seconds
# 2720
# Elapsed time: 145.2335 seconds
# 2730
# Elapsed time: 148.0639 seconds
# 2740
# Elapsed time: 151.4232 seconds
# 2750
# Elapsed time: 153.9580 seconds
# 2760
# Elapsed time: 156.4751 seconds
# 2770
# Elapsed time: 158.9963 seconds
# 2780
# Elapsed time: 162.2976 seconds
# 2790
# Elapsed time: 166.2947 seconds
# 2800
# Elapsed time: 168.9589 seconds
# 2810
# Elapsed time: 173.2500 seconds
# 2820
# Elapsed time: 176.6306 seconds
# 2830
# Elapsed time: 180.6453 seconds
# 2840
# Elapsed time: 184.0299 seconds
# 2850
# Elapsed time: 187.2631 seconds
# 2860
# Elapsed time: 190.9100 seconds
# 2870
# Elapsed time: 194.2678 seconds
# 2880
# Elapsed time: 197.1508 seconds
# 2890
# Elapsed time: 199.6164 seconds
# 2900
# Elapsed time: 201.9531 seconds
# 2910
# Elapsed time: 204.5577 seconds
# 2920
# Elapsed time: 206.4228 seconds
# 2930
# Elapsed time: 208.3581 seconds
# 2940
# Elapsed time: 210.3071 seconds
# 2950
# Elapsed time: 213.0695 seconds
# 2960
# Elapsed time: 215.7116 seconds
# 2970
# Elapsed time: 217.9648 seconds
# 2980
# Elapsed time: 219.9639 seconds
# 2990
# Elapsed time: 221.9599 seconds
# 3000
# Elapsed time: 224.1410 seconds
# 3010
# Elapsed time: 225.6913 seconds
# 3020
# Elapsed time: 227.9573 seconds
# 3030
# Elapsed time: 230.3571 seconds
# 3040
# Elapsed time: 233.1910 seconds
# 3050
# Elapsed time: 235.7169 seconds
# 3060
# Elapsed time: 238.2238 seconds
# 3070
# Elapsed time: 241.3240 seconds
# 3080
# Elapsed time: 244.4235 seconds
# 3090
# Elapsed time: 247.1300 seconds
# 3100
# Elapsed time: 250.5120 seconds
# 3110
# Elapsed time: 254.5277 seconds
# 3120
# Elapsed time: 257.7028 seconds
# 3130
# Elapsed time: 260.2750 seconds
# 3140
# Elapsed time: 262.7975 seconds
# 3150
# Elapsed time: 265.4541 seconds
# 3160
# Elapsed time: 269.2012 seconds
# 3170
# Elapsed time: 272.6946 seconds
# 3180
# Elapsed time: 277.1130 seconds
# 3190
# Elapsed time: 279.8316 seconds
# 3200
# Elapsed time: 282.7641 seconds
# 3210
# Elapsed time: 284.6330 seconds
# 3220
# Elapsed time: 287.1133 seconds
# 3230
# Elapsed time: 289.5561 seconds
# 3240
# Elapsed time: 291.9173 seconds
# 3250
# Elapsed time: 294.0128 seconds
# 3260
# Elapsed time: 296.3419 seconds
# 3270
# Elapsed time: 298.4194 seconds
# 3280
# Elapsed time: 300.2152 seconds
# 3290
# Elapsed time: 302.0270 seconds
# 3300
# Elapsed time: 304.2218 seconds
# 3310
# Elapsed time: 306.4856 seconds
# 3320
# Elapsed time: 308.4507 seconds
# 3330
# Elapsed time: 310.8460 seconds
# 3340
# Elapsed time: 312.9771 seconds
# 3350
# Elapsed time: 314.9042 seconds
# 3360
# Elapsed time: 316.8911 seconds
# 3370
# Elapsed time: 318.8173 seconds
# 3380
# Elapsed time: 320.9046 seconds
# 3390
# Elapsed time: 323.1021 seconds
# 3400
# Elapsed time: 325.6123 seconds
# 3410
# Elapsed time: 328.1517 seconds
# 3420
# Elapsed time: 330.1281 seconds
# 3430
# Elapsed time: 332.5045 seconds
# 3440
# Elapsed time: 334.8749 seconds
# 3450
# Elapsed time: 337.3125 seconds
# 3460
# Elapsed time: 340.3087 seconds
# 3470
# Elapsed time: 343.4898 seconds
# 3480
# Elapsed time: 346.3487 seconds
# 3490
# Elapsed time: 350.3282 seconds
# 3500
# Elapsed time: 354.5095 seconds
# 3510
# Elapsed time: 359.1449 seconds
# 3520
# Elapsed time: 362.8020 seconds
# 3530
# Elapsed time: 366.0748 seconds
# 3540
# Elapsed time: 368.8161 seconds
# 3550
# Elapsed time: 371.4395 seconds
# 3560
# Elapsed time: 374.6267 seconds
# 3570
# Elapsed time: 378.5711 seconds
# 3580
# Elapsed time: 382.1373 seconds
# 3590
# Elapsed time: 385.2977 seconds
# 3600
# Elapsed time: 387.8735 seconds
# 3610
# Elapsed time: 391.2560 seconds
# 3620
# Elapsed time: 394.2339 seconds
# 3630
# Elapsed time: 397.0731 seconds
# 3640
# Elapsed time: 399.0366 seconds
# 3650
# Elapsed time: 401.2157 seconds
# 3660
# Elapsed time: 403.4438 seconds
# 3670
# Elapsed time: 405.5808 seconds
# 3680
# Elapsed time: 407.7660 seconds
# 3690
# Elapsed time: 409.8000 seconds
# 3700
# Elapsed time: 411.7042 seconds
# 3710
# Elapsed time: 413.6004 seconds
# 3720
# Elapsed time: 416.1390 seconds
# 3730
# Elapsed time: 418.9814 seconds
# 3740
# Elapsed time: 421.2727 seconds
# 3750
# Elapsed time: 423.5352 seconds
# 3760
# Elapsed time: 425.4326 seconds
# 3770
# Elapsed time: 427.3675 seconds
# 3780
# Elapsed time: 429.4360 seconds
# 3790
# Elapsed time: 431.6445 seconds
# 3800
# Elapsed time: 434.1227 seconds
# 3810
# Elapsed time: 437.1719 seconds
# 3820
# Elapsed time: 440.5330 seconds
# 3830
# Elapsed time: 443.4656 seconds
# 3840
# Elapsed time: 446.8640 seconds
# 3850
# Elapsed time: 450.8353 seconds
# 3860
# Elapsed time: 456.2641 seconds
# 3870
# Elapsed time: 461.2126 seconds
# 3880
# Elapsed time: 466.0849 seconds
# 3890
# Elapsed time: 471.0955 seconds
# 3900
# Elapsed time: 475.6057 seconds
# 3910
# Elapsed time: 480.2284 seconds
# 3920
# Elapsed time: 483.6730 seconds
# 3930
# Elapsed time: 487.5459 seconds
# 3940
# Elapsed time: 490.3468 seconds
# 3950
# Elapsed time: 492.7612 seconds
# 3960
# Elapsed time: 495.0010 seconds
# 3970
# Elapsed time: 497.6825 seconds
# 3980
# Elapsed time: 500.6460 seconds
# 3990
# Elapsed time: 503.2748 seconds
# 4000
# Elapsed time: 505.8269 seconds
# 4010
# Elapsed time: 508.4610 seconds
# 4020
# Elapsed time: 511.5191 seconds
# 4030
# Elapsed time: 514.0857 seconds
# 4040
# Elapsed time: 516.4309 seconds
# 4050
# Elapsed time: 518.6236 seconds
# 4060
# Elapsed time: 521.0121 seconds
# 4070
# Elapsed time: 523.0719 seconds
# 4080
# Elapsed time: 524.7580 seconds
# 4090
# Elapsed time: 526.3829 seconds
# 4100
# Elapsed time: 528.4834 seconds
# 4110
# Elapsed time: 530.9482 seconds
# 4120
# Elapsed time: 533.4381 seconds
# 4130
# Elapsed time: 536.2852 seconds
# 4140
# Elapsed time: 539.4849 seconds
# 4150
# Elapsed time: 541.7844 seconds
# 4160
# Elapsed time: 544.7729 seconds
# 4170
# Elapsed time: 547.3697 seconds
# 4180
# Elapsed time: 550.7001 seconds
# 4190
# Elapsed time: 553.1430 seconds
# 4200
# Elapsed time: 555.7229 seconds
# 4210
# Elapsed time: 558.2098 seconds
# 4220
# Elapsed time: 561.0463 seconds
# 4230
# Elapsed time: 565.0585 seconds
# 4240
# Elapsed time: 568.7115 seconds
# 4250
# Elapsed time: 573.1195 seconds
# 4260
# Elapsed time: 578.3330 seconds
# 4270
# Elapsed time: 582.9873 seconds
# 4280
# Elapsed time: 586.4856 seconds
# 4290
# Elapsed time: 590.0592 seconds
# 4300
# Elapsed time: 593.6396 seconds
# 4310
# Elapsed time: 597.0414 seconds
# 4320
# Elapsed time: 600.3094 seconds
# 4330
# Elapsed time: 604.3502 seconds
# 4340
# Elapsed time: 607.5310 seconds
# 4350
# Elapsed time: 610.7587 seconds
# 4360
# Elapsed time: 614.2008 seconds
# 4370
# Elapsed time: 617.5530 seconds
# 4380
# Elapsed time: 620.3730 seconds
# 4390
# Elapsed time: 622.8296 seconds
# 4400
# Elapsed time: 624.4470 seconds
# 4410
# Elapsed time: 626.3341 seconds
# 4420
# Elapsed time: 628.6689 seconds
# 4430
# Elapsed time: 631.3206 seconds
# 4440
# Elapsed time: 634.3819 seconds
# 4450
# Elapsed time: 637.0817 seconds
# 4460
# Elapsed time: 639.0670 seconds
# 4470
# Elapsed time: 641.6566 seconds
# 4480
# Elapsed time: 644.0362 seconds
# 4490
# Elapsed time: 647.1518 seconds
# 4500
# Elapsed time: 649.7598 seconds
# 4510
# Elapsed time: 653.0255 seconds
# 4520
# Elapsed time: 655.0913 seconds
# 4530
# Elapsed time: 657.7203 seconds
# 4540
# Elapsed time: 660.2624 seconds
# 4550
# Elapsed time: 663.1849 seconds
# 4560
# Elapsed time: 665.4085 seconds
# 4570
# Elapsed time: 668.6891 seconds
# 4580
# Elapsed time: 673.0353 seconds
# 4590
# Elapsed time: 677.0963 seconds
# 4600
# Elapsed time: 680.1506 seconds
# 4610
# Elapsed time: 684.1173 seconds
# 4620
# Elapsed time: 688.8667 seconds
# 4630
# Elapsed time: 693.2009 seconds
# 4640
# Elapsed time: 697.3182 seconds
# 4650
# Elapsed time: 701.5244 seconds
# 4660
# Elapsed time: 704.8826 seconds
# 4670
# Elapsed time: 708.1918 seconds
# 4680
# Elapsed time: 711.4956 seconds
# 4690
# Elapsed time: 714.7782 seconds
# 4700
# Elapsed time: 718.0166 seconds
# 4710
# Elapsed time: 720.6431 seconds
# 4720
# Elapsed time: 723.6730 seconds
# 4730
# Elapsed time: 726.4222 seconds
# 4740
# Elapsed time: 728.6466 seconds
# 4750
# Elapsed time: 731.1421 seconds
# 4760
# Elapsed time: 733.5658 seconds
# 4770
# Elapsed time: 735.4473 seconds
# 4780
# Elapsed time: 737.8206 seconds
# 4790
# Elapsed time: 740.3162 seconds
# 4800
# Elapsed time: 742.6266 seconds
# 4810
# Elapsed time: 744.9228 seconds
# 4820
# Elapsed time: 747.0171 seconds
# 4830
# Elapsed time: 749.6430 seconds
# 4840
# Elapsed time: 752.1230 seconds
# 4850
# Elapsed time: 755.2016 seconds
# 4860
# Elapsed time: 757.7268 seconds
# 4870
# Elapsed time: 760.3127 seconds
# 4880
# Elapsed time: 762.3411 seconds
# 4890
# Elapsed time: 764.4304 seconds
# 4900
# Elapsed time: 766.8070 seconds
# 4910
# Elapsed time: 769.9506 seconds
# 4920
# Elapsed time: 774.0924 seconds
# 4930
# Elapsed time: 777.6414 seconds
# 4940
# Elapsed time: 780.9928 seconds
# 4950
# Elapsed time: 785.2796 seconds
# 4960
# Elapsed time: 790.5294 seconds
# 4970
# Elapsed time: 796.1747 seconds
# 4980
# Elapsed time: 800.5900 seconds
# 4990
# Elapsed time: 806.1702 seconds
# 5000
# Elapsed time: 810.7424 seconds
# 5010
# Elapsed time: 816.1458 seconds
# 5020
# Elapsed time: 821.8774 seconds
# 5030
# Elapsed time: 825.8221 seconds
# 5040
# Elapsed time: 830.2757 seconds
# 5050
# Elapsed time: 833.1531 seconds
# 5060
# Elapsed time: 835.9739 seconds
# 5070
# Elapsed time: 838.4332 seconds
# 5080
# Elapsed time: 840.8011 seconds
# 5090
# Elapsed time: 843.2933 seconds
# 5100
# Elapsed time: 845.8201 seconds
# 5110
# Elapsed time: 847.7817 seconds
# 5120
# Elapsed time: 850.0362 seconds
# 5130
# Elapsed time: 852.4001 seconds
# 5140
# Elapsed time: 854.8868 seconds
# 5150
# Elapsed time: 857.3510 seconds
# 5160
# Elapsed time: 859.5205 seconds
# 5170
# Elapsed time: 861.6051 seconds
# 5180
# Elapsed time: 863.8463 seconds
# 5190
# Elapsed time: 865.9260 seconds
# 5200
# Elapsed time: 867.5885 seconds
# 5210
# Elapsed time: 869.8374 seconds
# 5220
# Elapsed time: 872.1108 seconds
# 5230
# Elapsed time: 874.3283 seconds
# 5240
# Elapsed time: 877.0601 seconds
# 5250
# Elapsed time: 880.0095 seconds
# 5260
# Elapsed time: 882.5656 seconds
# 5270
# Elapsed time: 885.8368 seconds
# 5280
# Elapsed time: 888.8959 seconds
# 5290
# Elapsed time: 892.2277 seconds
# 5300
# Elapsed time: 895.8578 seconds
# 5310
# Elapsed time: 899.9910 seconds
# 5320
# Elapsed time: 904.1188 seconds
# 5330
# Elapsed time: 908.0963 seconds
# 5340
# Elapsed time: 913.1015 seconds
# 5350
# Elapsed time: 917.3446 seconds
# 5360
# Elapsed time: 921.4291 seconds
# 5370
# Elapsed time: 925.6694 seconds
# 5380
# Elapsed time: 929.4935 seconds
# 5390
# Elapsed time: 932.4844 seconds
# 5400
# Elapsed time: 935.2035 seconds
# 5410
# Elapsed time: 938.1049 seconds
# 5420
# Elapsed time: 941.1305 seconds
# 5430
# Elapsed time: 943.9620 seconds
# 5440
# Elapsed time: 947.0857 seconds
# 5450
# Elapsed time: 949.3840 seconds
# 5460
# Elapsed time: 951.2747 seconds
# 5470
# Elapsed time: 960.8238 seconds
