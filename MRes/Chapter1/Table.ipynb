# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data for the table
data = [
    ["The MODE Group, 1978", "Changed", "–", "AE & CE", "Observation", "0–1,500", "North Atlantic", "Centers observed as extremas in stream function and temperature field."],
    ["Bernstein & White, 1982", "Westward", "∼110", "AE", "Observation", "0–500", "Kuroshio Extension", "Centers observed as extremas in the temperature field."],
    ["Bennett & White, 1986", "Westward", "–", "AE", "Observation", "0–400", "North Pacific", "–"],
    ["Hua, 1988", "Changed", "∼100", "AE", "Observation", "0–4,000", "North Atlantic", "Extracted eddy as 0.85 isocontour from 3D streamfunction field."],
    ["Roemmich & Gilson, 2001", "Westward", "∼90", "AEs & CEs", "Composite", "0–400", "North Pacific", "Centers defined as extrema in averaged temperature anomaly."],
    ["Qiu & Chen, 2005", "Westward", "–", "AEs & CEs", "Observation", "0–200", "North Pacific", "By observing temperature anomaly shift within the eddy."],
    ["Hu et al., 2011", "Southwest*", "–", "CE", "Observation", "0–300", "Eastern SCS", "By observing temperature and salinity fields"],
    ["Chen et al., 2012", "Westward", "∼100", "Two AEs", "Observation", "0–800", "SCS", "By observing meridional geostrophic flow, temperature anomaly, and salinity anomaly fields."],
    ["Kurczyn et al., 2013", "Eastward", "150", "CE", "Observation", "0–750", "Northeast Pacific", "By observing kinematic fields (geostrophic velocity and normalised vorticity) and \nthermodynamic fields (potential temperature, salinity, and dissolved oxygen)."],
    ["Zhang et al., 2016", "Southwest*", "100–150", "Two AEs, a CE", "Observation", "100–2,000", "NSCS", "Topographic beta effect"],
    ["Amores et al., 2017", "Westward", "–", "AEs & CEs", "Composite", "0–200", "North Atlantic", "–"],
    ["Shu et al., 2019", "Southwest*", "<50", "AE", "Observation", "0–1,000", "NSCS", "Topographic beta effect"],
    ["Patel et al., 2019", "Westward", "<20", "CE", "Observation", "0–500", "Southern Ocean", "–"],
    ["Belkin et al., 2020", "Westward & Eastward", "∼5", "AE", "Observation", "0–750", "Gulf Stream", "–"],
    ["Tang et al., 2020", "Northwestward", "∼25", "AE", "Observation", "0–900", "Alaska", "Wind stress induced Ekman advection"],
    ["Ni et al., 2021", "Westward", "–", "AEs & CEs", "Composite", "0–1,000", "Global ocean", "Eddy-advection background temperature gradient"],
    ["Li et al., 2022a", "Northwestward, Southwestward", "10–400", "AEs & CEs", "Composite", "10–300", "Global ocean", "–"],
    ["Hu et al., 2022", "Eastward", "∼40", "AE", "Observation", "0–300", "Equatorial Indian", "–"],
    ["Sun et al., 2022", "Southwest*", "∼40", "AE", "Observation", "150–1,000", "NSCS", "Baroclinic instability"],
    ["Stern, 1965", "–", "–", "AE", "Model", "Above the thermocline", "Mid-latitude", "Wind-eddy interactions"],
    ["Lin et al., 2015", "Southwest", "∼50", "AE & CE", "Model", "0–700", "SCS", "–"],
    ["He et al., 2015", "Westward", "–", "CE", "Model", "0–700", "SCS", "–"],
    ["Liao et al., 2019", "Changed", "–", "AE", "Model", "0–3,000", "Tropics (20°N)", "Dispersive translation path of eddy with depth"],
    ["Mason et al., 2019", "Changed", "∼100", "AE & CE", "Model", "0–2,500", "Mediterranean", "–"],
    ["Yang et al., 2020", "Westward*, Eastward*", "∼25", "AE & CE", "Model", "0–1,000", "NSCS", "Nonlinear advection and planetary beta"],
    ["Li et al., 2020", "Changed", "∼100", "AE & CE", "Reanalysis", "0–2,300", "Eastern Australian", "Eddy-eddy (mean flow) interactions"],
    ["Li et al., 2022b", "Changed", "20–400", "AEs & CEs", "Composite, reanalysis, and model", "10–1,500", "Global ocean", "Depth dependent translation speed of eddies (waves)"]
]

# New column order
columns = ["Author", "Tilting direction", "Tilting distance (km)", "Type", "Data", "Depth (m)", "Region", "Method"]

# Create a pandas DataFrame
df = pd.DataFrame(data, columns=columns)

# Plot the table
fig, ax = plt.subplots(figsize=(12, 10))  # Adjust size to fit content
ax.axis('off')  # Turn off the axis
tbl = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')

# Make column headers bold
for key, cell in tbl.get_celld().items():
    if key[0] == 0:  # Row 0 corresponds to the header row
        cell.set_text_props(fontweight='bold')

# Adjust table properties for better readability
tbl.auto_set_font_size(False)
tbl.set_fontsize(10)
tbl.auto_set_column_width(col=list(range(len(columns))))
tbl.scale(1, 3)  # Scale rows for more vertical spacing

# Save the table as an image (optional)
plt.savefig("table_figure.png", dpi=300, bbox_inches='tight')

# Show the table
plt.show()
